# %% [markdown]
# ## Visualize Data

# %%
import pandas as pd

fname = '../DATA/202409/20240911.csv'
df = pd.read_csv(fname)

# %%
import matplotlib.pyplot as plt
plt.yscale('log')
plt.plot(df['date'], -1*df['current_mean'])

# %%
import numpy as np

fname = '../DATA/keysight/test_char_snake_data_00009.npz.npy'
data = np.load(fname)

# %%
# !ls ../DATA/keysight

# %%
plt.plot(data['time'], data['CHAR'])
